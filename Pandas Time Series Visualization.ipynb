# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

#For interactive plots that you can zoom, go to previous, use cursor to move around etc
#Restart the kernel and change matplotlib inline to matplotlib notebook and when you run the plots they become interactive

# %%
mcd = pd.read_csv('mcdonalds.csv', index_col='Date', parse_dates=True)

# %%
mcd.head()
# Out:
#             Adj. Close  Adj. Volume
# Date
# 1970-01-02    0.209761    2825604.0
# 1970-01-05    0.213316    2210449.5
# 1970-01-06    0.214501    1951168.5
# 1970-01-07    0.213316    2728768.5
# 1970-01-08    0.213316    2242404.0

# %%
#If your 2 columns are on a totally different scales then it wont come out right
#Plot the two columns separately, (call a series), adj.close is a series
mcd.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
mcd['Adj. Close'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
mcd['Adj. Volume'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
mcd['Adj. Volume'].plot(figsize=(12,4))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
mcd['Adj. Close'].plot(figsize=(12,4), xlim=['2007-01-01', '2009-01-01'], ylim=(30,50))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
mcd['Adj. Volume'].plot(figsize=(12,4), xlim=['2007-01-01', '2009-01-01'])
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
#If we want to show more details in our x axis like daily
idx = mcd.index
idx
# Out:
# DatetimeIndex(['1970-01-02', '1970-01-05', '1970-01-06', '1970-01-07',
#                '1970-01-08', '1970-01-09', '1970-01-12', '1970-01-13',
#                '1970-01-14', '1970-01-15',
#                ...
#                '2017-06-30', '2017-07-03', '2017-07-05', '2017-07-06',
#                '2017-07-07', '2017-07-10', '2017-07-11', '2017-07-12',
#                '2017-07-13', '2017-07-14'],
#               dtype='datetime64[ns]', name='Date', length=11993, freq=None)

# %%
idx = mcd.loc['2007-01-01':'2007-05-01'].index
#using : (colon) cuz we are slicing the dates of off the total
#.index at the end to actually call the index

# %%
idx
# Out:
# DatetimeIndex(['2007-01-03', '2007-01-04', '2007-01-05', '2007-01-08',
#                '2007-01-09', '2007-01-10', '2007-01-11', '2007-01-12',
#                '2007-01-16', '2007-01-17', '2007-01-18', '2007-01-19',
#                '2007-01-22', '2007-01-23', '2007-01-24', '2007-01-25',
#                '2007-01-26', '2007-01-29', '2007-01-30', '2007-01-31',
#                '2007-02-01', '2007-02-02', '2007-02-05', '2007-02-06',
#                '2007-02-07', '2007-02-08', '2007-02-09', '2007-02-12',
#                '2007-02-13', '2007-02-14', '2007-02-15', '2007-02-16',
#                '2007-02-20', '2007-02-21', '2007-02-22', '2007-02-23',
#                '2007-02-26', '2007-02-27', '2007-02-28', '2007-03-01',
#                '2007-03-02', '2007-03-05', '2007-03-06', '2007-03-07',
#                '2007-03-08', '2007-03-09', '2007-03-12', '2007-03-13',
#                '2007-03-14', '2007-03-15', '2007-03-16', '2007-03-19',
# ...

# %%
stock = mcd.loc['2007-01-01':'2007-05-01']['Adj. Volume']
stock
# Out:
# Date
# 2007-01-03    7579100.0
# 2007-01-04    9776100.0
# 2007-01-05    5701000.0
# 2007-01-08    4538500.0
# 2007-01-09    6832800.0
#                 ...
# 2007-04-25    6984800.0
# 2007-04-26    6849500.0
# 2007-04-27    4018000.0
# 2007-04-30    8216000.0
# 2007-05-01    6510400.0
# Name: Adj. Volume, Length: 82, dtype: float64

# %%
#Use plt_date so matplotlib knows youre usimg date so you can call mond=ths year day off  of it
fig,ax = plt.subplots()
ax.plot_date(idx,stock,'-')
ax.yaxis.grid(True) #ax.xaxis.grid(True)

fig.autofmt_xdate() #automatically format the x date axis, so they dont overlap each other

# %%
from datetime import datetime

# %%
#Locating
fig,ax = plt.subplots()
ax.plot_date(idx,stock,'-')

#Locating
ax.xaxis.set_major_locator(dates.MonthLocator())
#Formatting
ax.xaxis.set_major_formatter(dates.DateFormatter('\n\n\n\n%b--%Y'))#%b(small b) is the month abbr, %Y(capital y) is year full

ax.xaxis.set_minor_locator(dates.WeekdayLocator(byweekday=0))#0 is monday, 1 is tuesday
ax.xaxis.set_minor_formatter(dates.DateFormatter('%d'))#will only show monday dates like 01, 08 then 15 then 22....%a will show all mondays

ax.yaxis.grid(True)
fig.autofmt_xdate()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-06f9d2fbbb45> in <module>
#       4
#       5 #Locating
# ----> 6 ax.xaxis.set_major_locator(dates.MonthLocator())
#       7 #Formatting
#       8 ax.xaxis.set_major_formatter(dates.DateFormatter('\n\n\n\n%b--%Y'))#%b(small b) is the month abbr, %Y(capital y) is year full
#
# NameError: name 'dates' is not defined
