# %%
import pandas as pd
import numpy as np

# %%
pwd
#This is to get the location of your jupyter notebook
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-b76212143b84> in <module>
# ----> 1 pwd
#       2 #This is to get the location of your jupyter notebook
#
# NameError: name 'pwd' is not defined

# %%
df = pd.read_csv('calls.csv')
df
#Click Tab when typing in the dataset name to auto complete it
# Out:
#              user        other direction  duration  \
# 0      7610039694  07434677419  Incoming       211
# 1      7641036117  01666472054  Outgoing        31
# 2      7641036117  07371326239  Incoming        45
# 3      7641036117  07681546436  Outgoing        10
# 4      7641036117  07681546436  Outgoing         0
# ...           ...          ...       ...       ...
# 13030  7981267897  07641036117  Incoming        17
# 13031  7981267897  07156849982  Incoming        36
# 13032  7981267897  07681546436  Incoming        25
# 13033  7981267897  07784425582    Missed         0
# 13034  7981267897  07784425582  Incoming       454
#
#                             timestamp
# 0      Wed Sep 15 19:17:44 +0100 2010
# 1      Mon Feb 11 07:18:23 +0000 1980
# 2      Mon Feb 11 07:45:42 +0000 1980
# 3      Mon Feb 11 08:04:42 +0000 1980
# 4      Mon Feb 11 08:05:31 +0000 1980
# ...                               ...
# 13030  Fri Jan 28 19:15:00 +0000 2011
# ...

# %%
df = pd.read_excel('Excel_Sample.xlsx')
df
#Just click Tab after read_ to show the list of formats you can read FROM
# Out:
#    Unnamed: 0   a   b   c   d
# 0           0   0   1   2   3
# 1           1   4   5   6   7
# 2           2   8   9  10  11
# 3           3  12  13  14  15

# %%
df.to_csv('Dimz')
#Use .to_ to read to or change to or save as
#I changed the excel to csv

# %%
pd.read_csv('Dimz')
# Out:
#    Unnamed: 0  Unnamed: 0.1   a   b   c   d
# 0           0             0   0   1   2   3
# 1           1             1   4   5   6   7
# 2           2             2   8   9  10  11
# 3           3             3  12  13  14  15

# %%
df.to_csv('Dimz', index=False)
pd.read_csv('Dimz')
#Use index = false to remove the unnamed:0 column
# Out:
#    Unnamed: 0   a   b   c   d
# 0           0   0   1   2   3
# 1           1   4   5   6   7
# 2           2   8   9  10  11
# 3           3  12  13  14  15

# %%
df = pd.read_excel('Excel_Sample.xlsx', sheet_name='Sheet1', index_col=0)
df
#Always read through the parameter display, index col to '0' instead of default 'None' so 'unnamed 0:' will disappear
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
df = pd.read_excel('Excel_Sample.xlsx')
df
# Out:
#    Unnamed: 0   a   b   c   d
# 0           0   0   1   2   3
# 1           1   4   5   6   7
# 2           2   8   9  10  11
# 3           3  12  13  14  15

# %%
data = pd.read_html('https://www.flashscore.com.ng/')
data[0].head()
#Pandas will try to read all the tables in the html link and store them as a list
#[0] is to select the first list or table it has saved which is our dataset

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine('sqlite:///:memory:')
#This line of code has created a temp very small sqlite engine database(db) that's running in memory

# %%
df.to_sql('my_tab', engine)
#parameters is name then connection(con), which is just engine here
#The shift tab always shows you the parameters so always read through them

# %%
sqldf = pd.read_sql('my_tab',con=engine)
sqldf
# Out:
#    index  Unnamed: 0   a   b   c   d
# 0      0           0   0   1   2   3
# 1      1           1   4   5   6   7
# 2      2           2   8   9  10  11
# 3      3           3  12  13  14  15
